# %%
import os

# %%
import sys

# %%
# %pwd
# Out:
# 'c:\\Users\\l\\End-to-End-chest-cancer-classification-using--MLflow-DVC'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\l'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
pip install -e .
# Out:
# Obtaining file:///C:/Users/l
# Note: you may need to restart the kernel to use updated packages.
# ERROR: file:///C:/Users/l does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
pip install python-box
# Out:
# Requirement already satisfied: python-box in c:\users\l\miniconda3\miniconda\envs\cancer\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import Box

# %%
pip install PyYAML
# Out:
# Requirement already satisfied: PyYAML in c:\users\l\miniconda3\miniconda\envs\cancer\lib\site-packages (6.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\l\miniconda3\miniconda\envs\cancer\lib\site-packages (1.5.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
pip install ensure
# Out:
# Requirement already satisfied: ensure in c:\users\l\miniconda3\miniconda\envs\cancer\lib\site-packages (1.0.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\l\miniconda3\miniconda\envs\cancer\lib\site-packages (from ensure) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cnnClassifier.constants import*
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    
     
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    
    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[42], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# Cell In[39], line 7, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       2 def __init__(
#       3     self,
#       4     config_filepath = CONFIG_FILE_PATH,
#       5     params_filepath = PARAMS_FILE_PATH):
# ----> 7     self.config = read_yaml(config_filepath)
#       8     self.params = read_yaml(params_filepath)
#      10     create_directories([self.config.artifacts_root])
#
# File c:\Users\l\miniconda3\miniconda\envs\cancer\lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File ~\End-to-End-chest-cancer-classification-using--MLflow-DVC\src\cnnClassifier\utils\common.py:38, in read_yaml(path_to_yaml)
#      36     raise ValueError("yaml file is empty")
#      37 except Exception as e:
# ---> 38     raise e
#
# File ~\End-to-End-chest-cancer-classification-using--MLflow-DVC\src\cnnClassifier\utils\common.py:31, in read_yaml(path_to_yaml)
#      18 """reads yaml file and returns
#      19
#      20 Args:
#    (...)
#      28     ConfigBox: ConfigBox type
#      29 """
#      30 try:
# ---> 31     with open(path_to_yaml) as yaml_file:
#      32         content = yaml.safe_load(yaml_file)
#      33         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'
